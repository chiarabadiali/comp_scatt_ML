# %%
import pandas as pd 
import numpy as np
import math
import tensorflow as tf
import matplotlib.pyplot as plt
print(pd.__version__)
import progressbar
# Out:
# 1.2.0

# %% [markdown]
# ## Print Dependencies
#
#
#
# Dependences are fundamental to record the computational environment.

# %%
# %load_ext watermark

# python, ipython, packages, and machine characteristics
# %watermark -v -m -p pandas,keras,numpy,math,tensorflow,matplotlib,h5py

# date
print (" ")
# %watermark -u -n -t -z
# Out:
# Python implementation: CPython
# Python version       : 3.7.7
# IPython version      : 7.19.0
#
# pandas    : 1.2.0
# keras     : 2.4.3
# numpy     : 1.19.5
# math      : unknown
# tensorflow: 2.4.0
# matplotlib: 3.3.3
# h5py      : 2.10.0
#
# Compiler    : GCC 5.4.0 20160609
# OS          : Linux
# Release     : 5.8.0-40-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 8
# Architecture: 64bit
#
#
# Last updated: Thu Jan 28 2021 11:23:53CET

# %% [markdown]
# ## Load of the test data

# %%
from process import loaddata
regr_data = loaddata("../data/regression/100-high-ene.csv")
class_data = loaddata("../data/classifier/100-high-ene.csv")

# %%
np.random.shuffle(class_data)
yc_test = class_data[:,0]
xc_test = class_data[:,1:]

# %%
np.random.shuffle(regr_data)
yr_test = regr_data[:,-3:]
xr_test = regr_data[:,:6]

# %%
xc_test.shape
# Out:
# (72254, 10)

# %%
xr_test.shape
# Out:
# (36127, 6)

# %% [markdown]
# ## Model Build

# %%
from tensorflow import keras

# %%
model_regr = keras.models.load_model('../models/regression/large_mse250.h5')
model_class = keras.models.load_model('../models/classifier/with-dropout-250.h5')

# %% [markdown]
# ## Test of the Classification NN

# %%
model_class.fit(xc_test, yc_test)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 334438, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 334438, 10), dtype=tf.float32, name='dense_12_input'), name='dense_12_input', description="created by layer 'dense_12_input'"), but it was called on an input with incompatible shape (None, 10).
# 2258/2258 [==============================] - 3s 1ms/step - loss: 1.0596 - accuracy: 0.5934

# %% [markdown]
# ## Test of the Regression NN

# %%
model_regr.fit(xr_test, yr_test)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 167219, 6) for input KerasTensor(type_spec=TensorSpec(shape=(None, 167219, 6), dtype=tf.float32, name='dense_18_input'), name='dense_18_input', description="created by layer 'dense_18_input'"), but it was called on an input with incompatible shape (None, 6).
# 1129/1129 [==============================] - 3s 2ms/step - loss: 0.0151 - mae: 0.0581

# %% [markdown]
# ## Test spectrum

# %%
def energy_spectrum(energy_array, bins):
    energy_array = np.array(energy_array)
    plt.hist(energy_array, bins, histtype=u'step')
    plt.yscale("log")
    plt.show()

# %%
final_p = []
final_e = []

for regr_pair in regr_data:
    final_e.append(np.linalg.norm(regr_pair[10:13]))
    final_p.append(np.linalg.norm(regr_pair[13:16]))

# %%
energy_spectrum(final_e, 75)

# %%
energy_spectrum(final_p, 75)

# %%
photon_final_nn = []
threshold = 0.5
for i, x in enumerate(xc_test[:200]):
    if i%100 == 0:
        print("{}%".format(i/len(xc_test) * 100))
    x = np.array([x])
    classification = model_class.predict(np.stack(x))
    if classification >= threshold:
        regr_x = np.array([x[0,:6]])
        regr_result = model_regr.predict(regr_x)
        photon_final_nn.append(np.linalg.norm(regr_result[0]))
# Out:
# 0.0%
# WARNING:tensorflow:Model was constructed with shape (None, 334438, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 334438, 10), dtype=tf.float32, name='dense_12_input'), name='dense_12_input', description="created by layer 'dense_12_input'"), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 167219, 6) for input KerasTensor(type_spec=TensorSpec(shape=(None, 167219, 6), dtype=tf.float32, name='dense_18_input'), name='dense_18_input', description="created by layer 'dense_18_input'"), but it was called on an input with incompatible shape (None, 6).
# 0.1384006421789797%

# %%
from tensorflow import keras 
photon_final_nn = []
threshold = 0.5
num = int(0.5*len(xc_test))
bar = progressbar.ProgressBar(maxval=num, 
                              widgets=[progressbar.Bar('=', '[', ']'), ' ', 
                                       progressbar.Percentage(), 
                                       " of {0}".format(num)])
bar.start()
for i, x_ in enumerate(xc_test[:num]):
    x_ = np.array([x_])
    classification = model_class.predict(np.stack(x_))
    if classification >= threshold:
        regr_x = np.array([x_[0,:6]])
        regr_result = model_regr.predict(regr_x)
        photon_final_nn.append(np.linalg.norm(regr_result[0]))
    bar.update(i+1)
bar.finish()
# Out:
# [===============================================================] 100% of 36127

# %%
energy_spectrum(photon_final_nn, 75)

# %%
photon_final_nn
# Out:
# [0.0288184,
#  3.2355123,
#  0.07568455,
#  4.076888,
#  2.5729365,
#  4.2125535,
#  3.1596115,
#  0.14530951,
#  0.33190322,
#  1.8642199,
#  3.2043917,
#  0.39900032,
#  0.7296559,
#  0.11783351,
#  0.38854268,
#  1.0257887,
#  2.354761,
#  3.2244332,
#  4.1106334,
#  3.7872481,
#  0.70111024,
#  0.49338597,
#  0.037598006,
#  4.0009127,
#  1.9627904,
#  0.2711787,
#  3.2690272,
#  3.4355762,
#  8.253365,
#  0.082103096,
#  0.04438948,
#  0.9869515,
#  3.1223752,
#  2.9813805,
#  4.035385,
#  6.0031753,
#  0.2562387,
#  3.849952,
#  2.531843,
#  0.11717749,
#  0.37845382,
#  2.4006972,
#  0.15659675,
#  0.03742144,
#  1.6429985,
#  4.808432,
#  0.24138026,
#  0.33905405,
#  0.04438221,
#  2.7331758,
#  4.9976025,
#  0.6685323,
#  0.053492703,
#  0.058692202,
#  1.51981,
#  1.1290436,
#  10.267412,
#  3.1513824,
#  0.89605093,
#  0.91098666,
#  0.54713225,
#  3.1026545,
#  8.626786,
#  0.14382428,
#  1.2631147,
#  0.4781528,
#  0.07703462,
#  1.0914727,
#  0.053921603,
#  3.3879387,
#  16.268028,
#  0.15031055,
#  0.14988889,
#  3.8919048,
#  0.11451136,
#  0.21641192,
#  0.4218723,
#  1.7830011,
#  0.88487256,
#  0.090406045,
#  2.3082752,
#  0.23622738,
#  4.6296573,
#  0.67518115,
#  0.6509319,
#  0.98016435,
#  0.18337731,
#  4.3134522,
#  2.995916,
#  0.8488684,
#  0.1549765,
#  4.789808,
#  2.7456489,
#  4.014913,
#  0.92535925,
#  0.34324798,
#  0.29364666,
#  0.029813007,
#  0.09274151,
#  0.8309876,
#  1.581696,
#  4.7737074,
#  3.1042533,
#  0.5784302,
#  5.8225408,
#  0.0742095,
#  0.8860179,
#  0.08544846,
#  4.1906614,
#  0.12897168,
#  2.1573393,
#  0.3291378,
#  0.13721766,
#  0.21365744,
#  12.291087,
#  2.0180717,
#  0.12254718,
#  4.072622,
#  3.9363282,
#  0.57363844,
#  0.11691816,
#  3.250077,
#  0.2527045,
#  0.6547895,
#  0.7939598,
#  0.3450752,
#  3.019467,
#  0.9295685,
#  0.93897647,
#  1.0873327,
#  0.8010192,
#  2.392508,
#  12.184105,
#  0.39725325,
#  2.4051218,
#  0.11563439,
#  6.13897,
#  0.033571877,
#  2.3681316,
#  1.2555395,
#  0.70046604,
#  2.7159216,
#  0.07976324,
#  1.5617262,
#  0.31333077,
#  1.3420719,
#  1.1052535,
#  0.018333115,
#  0.10683119,
#  2.6784542,
#  7.4750347,
#  1.2038475,
#  1.1773282,
#  0.16895002,
#  2.2581615,
#  3.3196895,
#  0.6281922,
#  0.9086955,
#  1.8885474,
#  2.9882512,
#  2.9596238,
#  16.180136,
#  2.65305,
#  0.19072096,
#  1.4555687,
#  0.042845484,
#  3.894873,
#  0.21111901,
#  0.07775866,
#  2.2463477,
#  4.6878896,
#  1.1062902,
#  5.968575,
#  15.504683,
#  1.1037967,
#  0.76301813,
#  0.060391575,
#  0.15098815,
#  0.46385777,
#  0.25094584,
#  6.2493052,
#  2.6991568,
#  1.8745635,
#  5.990606,
#  5.402807,
#  0.3390358,
#  0.6338265,
#  1.0954093,
#  0.06273297,
#  3.6034088,
#  2.4666238,
#  0.0637274,
#  0.8573256,
#  5.3101363,
#  0.17730767,
#  0.41687435,
#  9.264909,
#  1.7267042,
#  2.0008242,
#  2.8629427,
#  9.1367235,
#  0.22504917,
#  0.08615478,
#  0.7264389,
#  4.714238,
#  1.8379174,
#  0.26214907,
#  0.2465075,
#  3.0059998,
#  5.715507,
#  2.0322347,
#  0.12588152,
#  0.32091346,
#  2.6377797,
#  6.4914565,
#  0.82354695,
#  0.06407173,
#  4.0108714,
#  1.2493467,
#  4.1749372,
#  1.5381354,
#  2.038632,
#  2.1678934,
#  0.14698447,
#  0.20786215,
#  1.5488805,
#  1.8257245,
#  2.1545167,
#  4.863054,
#  1.077802,
#  0.6059536,
#  0.3507089,
#  0.051201474,
#  1.1551346,
#  1.9524972,
#  0.28841972,
#  2.2994814,
#  1.3511233,
#  1.0302154,
#  0.08303274,
#  0.83710986,
#  0.48669478,
#  0.8747749,
#  7.1826,
#  0.18417788,
#  0.06538402,
#  5.2582016,
#  0.25131464,
#  12.46418,
#  0.13824596,
#  2.8515983,
#  0.19590952,
#  3.2718225,
#  0.08170157,
#  1.7411277,
#  0.94303215,
#  3.914474,
#  1.1733501,
#  0.052646007,
#  0.35065803,
#  0.123327754,
#  2.1204255,
#  0.37181434,
#  0.41383624,
#  0.06908338,
#  0.21336678,
#  0.3908272,
#  0.13629356,
#  2.1497068,
#  0.28473115,
#  1.2676936,
#  0.055237256,
#  1.5182984,
#  0.62469095,
#  2.1357746,
#  2.6342273,
#  0.1260427,
#  3.2228723,
#  4.931175,
#  0.1552059,
#  5.3945246,
#  0.99680066,
#  2.1668599,
#  1.5237194,
#  0.6693402,
#  0.3144884,
#  5.001322,
#  4.9857087,
#  9.557519,
#  2.333776,
#  0.6565454,
#  3.6373591,
#  0.8860445,
#  2.637485,
#  13.741419,
#  1.0447092,
#  3.1029294,
#  11.851142,
#  0.19702667,
#  3.1669388,
#  1.8283724,
#  1.2241392,
#  3.860806,
#  0.0666375,
#  7.1130114,
#  7.759789,
#  0.04274079,
#  2.116232,
#  2.0654814,
#  0.43637556,
#  1.963943,
#  0.59205157,
#  2.6261468,
#  12.7061405,
#  0.8719447,
#  1.5162928,
#  1.0717968,
#  0.09042825,
#  0.08537897,
#  0.15607806,
#  0.13247268,
#  6.9958487,
#  1.0440053,
#  3.513312,
#  1.4532812,
#  5.139618,
#  0.09359592,
#  0.12550563,
#  0.9204306,
#  1.3267261,
#  8.655683,
#  2.1317306,
#  0.24505042,
#  0.09928442,
#  0.27106956,
#  11.381657,
#  8.350467,
#  0.5255186,
#  0.7687697,
#  11.491293,
#  0.070693575,
#  3.5561543,
#  0.48668197,
#  3.1311955,
#  0.094423115,
#  1.0513296,
#  0.5769903,
#  1.6975411,
#  0.054876536,
#  3.436543,
#  2.9913602,
#  2.7643065,
#  1.4929746,
#  0.09169659,
#  2.3806,
#  0.04928396,
#  0.38086197,
#  1.1956509,
#  0.16263224,
#  4.02063,
#  2.3441825,
#  6.2558966,
#  8.252507,
#  0.57621956,
#  0.34767464,
#  2.0063512,
#  1.048567,
#  2.5759943,
#  0.07154173,
#  0.09086972,
#  1.9264195,
#  0.03374979,
#  2.188952,
#  0.2821672,
#  4.5505366,
#  0.37260246,
#  1.227663,
#  0.065325335,
#  0.21868178,
#  1.7105291,
#  0.1620186,
#  0.73795956,
#  15.263421,
#  5.3648515,
#  1.201996,
#  0.09329675,
#  0.44542292,
#  10.134947,
#  0.830961,
#  2.1719391,
#  0.2598181,
#  3.409395,
#  0.07894551,
#  0.07935882,
#  1.4492195,
#  14.839505,
#  0.32063934,
#  2.662224,
#  0.34635806,
#  0.743996,
#  3.738144,
#  1.7836218,
#  2.5246947,
#  0.6934824,
#  2.7314699,
#  3.0805695,
#  1.0772641,
#  2.5459867,
#  0.7516129,
#  12.817306,
#  12.612506,
#  0.91644275,
#  0.5213934,
#  0.30991492,
#  0.05451207,
#  0.7147138,
#  0.29000518,
#  22.522024,
#  0.31467122,
#  0.12906192,
#  0.35554343,
#  0.45458144,
#  7.7308455,
#  0.07329089,
#  5.5384088,
#  11.258659,
#  0.083450675,
#  1.1062148,
#  3.1539724,
#  5.2459874,
#  2.0311766,
#  5.4598966,
#  0.14461888,
#  0.050581027,
#  8.750163,
#  0.16290277,
#  1.4491374,
#  0.09662335,
#  0.06527128,
#  1.4912266,
#  0.66463786,
#  3.2815614,
#  1.1194108,
#  0.10708768,
#  0.9080342,
#  1.2514366,
#  0.020686932,
#  1.839206,
#  1.763432,
#  7.889815,
#  3.4277864,
#  1.4438257,
#  1.7085454,
#  1.4533799,
#  0.98415506,
#  0.38026613,
#  0.084968954,
#  0.58125794,
#  2.5437863,
#  1.6494201,
#  1.1718826,
#  5.4795938,
#  0.18796402,
#  0.19362757,
#  1.334847,
#  1.1987287,
#  0.6998645,
#  0.040138353,
#  0.6339162,
#  0.54653364,
#  1.0886672,
#  15.361871,
#  0.11173633,
#  0.5578553,
#  0.76748604,
#  0.44007307,
#  1.2123468,
#  1.3730146,
#  1.9110297,
#  0.04089822,
#  1.566729,
#  1.6769185,
#  1.1837509,
#  8.268546,
#  14.715,
#  2.9354396,
#  0.08745715,
#  0.88401455,
#  0.5086691,
#  2.9918935,
#  0.018430004,
#  2.1356966,
#  8.284216,
#  0.6805747,
#  0.5555156,
#  0.5570165,
#  3.530024,
#  1.9942727,
#  1.0030305,
#  0.064083226,
#  0.03905744,
#  6.7569757,
#  0.6991315,
#  0.0837782,
#  0.39540392,
#  0.83681715,
#  0.9520951,
#  0.6018581,
#  0.033566575,
#  2.2640994,
#  1.272336,
#  3.1358883,
#  16.02842,
#  16.847134,
#  0.49931163,
#  0.919927,
#  1.109059,
#  9.916512,
#  0.60985,
#  0.14567427,
#  13.028407,
#  0.11887383,
#  0.6366011,
#  4.4178734,
#  4.1000743,
#  0.46916348,
#  13.843718,
#  0.0948745,
#  1.8707298,
#  12.32677,
#  1.059174,
#  0.49466947,
#  2.0016408,
#  0.7993016,
#  2.6526232,
#  0.06179001,
#  0.3278917,
#  2.2401404,
#  8.049798,
#  0.80338967,
#  1.1358716,
#  0.9150957,
#  0.582169,
#  1.6348394,
#  0.23315862,
#  1.911801,
#  6.859291,
#  0.21814363,
#  13.371401,
#  0.1781042,
#  0.20018122,
#  9.814205,
#  0.27455628,
#  0.6120054,
#  0.09612273,
#  0.08391385,
#  0.097260706,
#  10.931558,
#  0.2823605,
#  1.337644,
#  2.3301816,
#  1.1048998,
#  0.108392976,
#  0.82058126,
#  1.3706492,
#  2.8279057,
#  3.9985962,
#  0.67353624,
#  0.5369631,
#  3.8613338,
#  0.066857055,
#  0.492609,
#  3.3482661,
#  0.18002298,
#  0.15823026,
#  0.8666237,
#  0.09736523,
#  0.21211605,
#  0.15076682,
#  1.6814147,
#  2.9308355,
#  2.967116,
#  3.1792173,
#  0.37309805,
#  0.038092613,
#  0.077020995,
#  6.0185103,
#  4.10359,
#  0.888316,
#  2.8063207,
#  7.789679,
#  3.3853126,
#  10.756224,
#  11.387922,
#  0.30899653,
#  2.3185244,
#  3.3892567,
#  8.367729,
#  4.732519,
#  1.1165718,
#  2.4074795,
#  5.047605,
#  1.2550867,
#  1.3894868,
#  5.5875983,
#  0.07030283,
#  0.26417673,
#  2.1313813,
#  2.8136933,
#  5.948679,
#  1.455366,
#  0.4545729,
#  4.6981616,
#  0.95968324,
#  0.9446458,
#  3.4125707,
#  0.03554522,
#  6.02719,
#  2.325823,
#  0.7828461,
#  4.748558,
#  2.6539207,
#  4.7764,
#  5.7967176,
#  1.2361927,
#  0.31775802,
#  1.3502774,
#  1.9798592,
#  0.16939741,
#  0.9271809,
#  0.81932926,
#  2.038924,
#  1.3374239,
#  2.654229,
#  0.06391655,
#  1.4875797,
#  1.5484327,
#  3.3461497,
#  1.724176,
#  2.2267992,
#  1.5540621,
#  0.16570579,
#  14.719142,
#  0.6530533,
#  0.8935976,
#  1.2704164,
#  0.30065906,
#  2.4796038,
#  0.32753435,
#  0.09004305,
#  2.6161034,
#  0.0576804,
#  0.70409495,
#  0.883351,
#  0.53376985,
#  0.0795999,
#  0.20445248,
#  1.117576,
#  0.045335717,
#  2.0318854,
#  1.1994035,
#  1.4385507,
#  13.267677,
#  0.21648215,
#  1.9393849,
#  0.06420248,
#  1.8723179,
#  1.028458,
#  0.062413447,
#  8.743994,
#  0.16489114,
#  0.915402,
#  0.17395322,
#  2.0717764,
#  0.21944244,
#  1.6137702,
#  10.423273,
#  10.2995205,
#  0.01702483,
#  0.63392484,
#  1.6417319,
#  2.5568638,
#  3.076924,
#  0.4118298,
#  2.9006639,
#  13.208745,
#  0.8487824,
#  0.123147115,
#  0.014810844,
#  0.059970036,
#  3.6913872,
#  1.1492306,
#  0.08609211,
#  2.530287,
#  3.6059468,
#  0.26024085,
#  0.12928511,
#  1.6350671,
#  3.5947592,
#  1.3108886,
#  2.2919323,
#  1.2496772,
#  1.808332,
#  0.55010307,
#  5.6740403,
#  1.0174525,
#  2.308116,
#  0.19807555,
#  0.14952411,
#  0.06581041,
#  0.9304039,
#  1.7872012,
#  1.1043714,
#  0.8479335,
#  0.034856576,
#  0.7413664,
#  3.037093,
#  7.5471344,
#  0.05365171,
#  0.07919041,
#  1.1070851,
#  1.4963204,
#  0.69492084,
#  4.0067415,
#  0.5511559,
#  0.9916167,
#  0.17126752,
#  1.3311064,
#  0.79997987,
#  0.6540502,
#  1.6745837,
#  4.895441,
#  0.33353284,
#  2.6098487,
#  0.03883626,
#  0.62348217,
#  0.10127318,
#  14.282547,
#  0.1582118,
#  2.2335455,
#  0.23273864,
#  0.8766156,
#  7.49847,
#  0.46880218,
#  0.23791265,
#  0.35340378,
#  8.056372,
#  0.058329046,
#  2.8200943,
#  0.22271943,
#  0.75780034,
#  5.3128037,
#  3.2343667,
#  0.05987901,
#  8.982055,
#  2.7293787,
#  16.159178,
#  0.05224801,
#  4.7520647,
#  0.17404413,
#  0.31487364,
#  8.626507,
#  3.999076,
#  0.06158365,
#  0.9134559,
#  0.098324925,
#  0.70670605,
#  5.0336757,
#  1.412604,
#  2.7029698,
#  0.09355417,
#  1.103161,
#  1.5373682,
#  0.15818872,
#  1.16397,
#  3.321903,
#  5.680695,
#  0.059732176,
#  1.6836754,
#  3.359107,
#  0.17634456,
#  2.1032019,
#  9.5318775,
#  0.2231764,
#  0.75484294,
#  2.2084305,
#  0.1499371,
#  7.6270156,
#  0.12498318,
#  5.207192,
#  10.098029,
#  6.2579474,
#  0.17776878,
#  2.4479423,
#  0.16763179,
#  4.7853756,
#  1.0516433,
#  1.4074239,
#  3.345541,
#  0.6838166,
#  0.7542806,
#  4.063113,
#  2.1055846,
#  0.2282763,
#  2.6459043,
#  5.7236023,
#  0.42095438,
#  1.5282165,
#  0.10272525,
#  8.071075,
#  19.447206,
#  1.5419807,
#  3.2360213,
#  1.1702482,
#  0.93792224,
#  0.056252956,
#  0.16964817,
#  0.30118516,
#  1.1193814,
#  0.7888524,
#  3.5649424,
#  0.38788563,
#  7.932637,
#  2.2224755,
#  2.8333566,
#  9.640806,
#  0.21214534,
#  0.43404284,
#  0.10508578,
#  0.95713043,
#  11.369667,
#  1.0177923,
#  0.11009848,
#  2.938151,
#  19.369896,
#  0.10345462,
#  3.184104,
#  2.2983594,
#  1.8023717,
#  0.046039116,
#  1.5265086,
#  0.44181874,
#  0.1241429,
#  11.35946,
#  0.34317097,
#  0.7326494,
#  1.0060369,
#  0.19117485,
#  2.3337958,
#  0.5961812,
#  0.5572337,
#  0.37167108,
#  1.4800429,
#  0.5704652,
#  6.3477235,
#  3.2291718,
#  0.4105207,
#  0.16290516,
#  1.390204,
#  1.1267648,
#  0.12880675,
#  0.9233561,
#  10.1913595,
#  0.115491524,
#  0.96338606,
#  0.025869522,
#  6.785011,
#  0.43243062,
#  0.082666285,
#  1.2482789,
#  5.4967294,
#  3.3575447,
#  1.5468688,
#  6.4181023,
#  0.0975004,
#  5.7598233,
#  0.07396316,
#  0.06770991,
#  3.212214,
#  0.8131387,
#  1.9162097,
#  4.7972565,
#  11.371761,
#  0.27902842,
#  1.7562135,
#  8.496538,
#  11.135765,
#  4.220567,
#  4.1292768,
#  1.3714737,
#  5.830582,
#  10.510333,
#  4.7408123,
#  0.23649997,
#  0.3055802,
#  0.28260794,
#  1.8066424,
#  0.24916394,
#  0.21476482,
#  1.1418561,
#  0.39843115,
#  8.043008,
#  2.3334358,
#  0.08198452,
#  0.15018722,
#  4.956846,
#  2.384575,
#  0.02950403,
#  0.98145115,
#  0.8493739,
#  0.14705308,
#  1.4437678,
#  0.8936111,
#  3.7501612,
#  0.96271074,
#  1.0804738,
#  0.6315548,
#  0.35159257,
#  1.0131812,
#  1.8820062,
#  14.482799,
#  5.696543,
#  0.043400053,
#  1.4179351,
#  7.9572024,
#  0.27877587,
#  0.42591402,
#  3.8739595,
#  0.9579726,
#  0.07358405,
#  2.2909176,
#  0.15931313,
#  4.3410063,
#  0.1321562,
#  4.8840423,
#  8.320285,
#  2.6243877,
#  2.2543752,
#  0.08289837,
#  3.3702245,
#  0.17155172,
#  0.6070983,
#  0.73368424,
#  1.3011011,
#  0.0267852,
#  0.7145132,
#  10.779229,
#  1.327296,
#  1.4996645,
#  0.55299306,
#  5.41991,
#  0.11171302,
#  3.9293675,
#  0.061156582,
#  0.5253635,
#  0.641315,
#  3.3918135,
#  0.9495584,
#  0.059903994,
#  3.3289847,
#  1.80458,
#  0.3793428,
#  14.534994,
#  1.2678958,
#  0.11461174,
#  0.27543274,
#  0.06822583,
#  2.3388398,
#  0.079564855,
#  0.30806196,
#  3.2054582,
#  0.38517082,
#  4.310295,
#  0.17862211,
#  0.4454349,
#  1.7394079,
#  0.08842021,
#  0.27105564,
#  2.0713973,
#  1.6215371,
#  1.3826563,
#  2.307771,
#  2.2910254,
#  1.0211633,
#  0.4001158,
#  3.7479844,
#  2.8402045,
#  0.2845358,
#  0.04418484,
#  0.6622743,
#  0.50231165,
#  4.998387,
#  0.17531708,
#  2.69634,
#  8.695419,
#  0.47364265,
#  0.9117067,
#  0.7974146,
#  1.2277662,
#  0.32838494,
#  ...]

# %%
plt.hist(photon_final_nn, 60, alpha=0.5, label='NN prediction', density = True)
plt.hist(final_p, 100, alpha=0.5, label='Photon Momentum from simulations', density = True)
plt.xlabel('Photon Momentum')
plt.yscale('log')
plt.ylabel('count')
plt.legend(loc='upper right')
plt.show()

# %%
fig, axs = plt.subplots(2, sharex = True)
fig.suptitle('Vertically stacked subplots')
axs[0].hist(photon_final_nn, 100, alpha=0.5, label='NN prediction', density = True)
axs[1].hist(final_p, 100, alpha=0.5, label='Photon Momentum from simulations', density = True)
fig.show()
# Out:
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """

# %%
from scipy.stats import norm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import scipy
import scipy.stats as stats
from scipy.stats import chisquare
from scipy.optimize import curve_fit

# %%
xmin, xmax = plt.xlim()
x_nn = np.linspace(0, 25, 100)
plt.hist(photon_final_nn, bins=20, alpha = 0.5, label='NN prediction', density = True)
P_nn = stats.expon.fit(photon_final_nn)
rP_nn = stats.expon.pdf(x_nn, *P_nn)
plt.yscale('log')
plt.plot(x_nn, rP_nn,'r--', label = 'fit NN', linewidth=2)
plt.legend(loc='upper right')
plt.show()

# %%
print("chi square = ", stats.chisquare(photon_final_nn))
# Out:
# chi square =  Power_divergenceResult(statistic=27340.596590024656, pvalue=0.0)

# %%
xmin, xmax = plt.xlim()
x = np.linspace(0, 25, 100)
plt.hist(photon_final_nn, bins=20, alpha = 0.5, label='NN prediction', density = True)
P = stats.expon.fit(final_p)
rP = stats.expon.pdf(x, *P)
plt.plot(x, rP,'r--', label = 'fit NN', linewidth=2)
plt.legend(loc='upper right')
plt.show()

# %%
print("chi square = ", stats.chisquare(final_p))
# Out:
# chi square =  Power_divergenceResult(statistic=161345.6928002635, pvalue=0.0)

# %%
plt.hist(photon_final_nn, bins=20, alpha = 0.5, label='NN prediction', density = True)
plt.hist(final_p, bins=20, alpha = 0.5, label='Photon Momentum from simulations', density = True)
plt.plot(x, rP,'r--', label = 'fit data', linewidth=2)
plt.plot(x_nn, rP_nn,'g:', label = 'fit NN', linewidth=2)
plt.yscale('log')
plt.legend(loc='upper right')
plt.ylim((0, 1))
plt.show()
# Out:
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   import sys
