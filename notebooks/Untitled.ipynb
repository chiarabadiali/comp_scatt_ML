# %%
import pandas as pd 
import numpy as np
import math
import tensorflow as tf
import matplotlib.pyplot as plt
print(pd.__version__)
import progressbar
import os
from os import listdir
from tensorflow import keras
# Out:
# 1.2.3

# %%
model_class = keras.models.load_model('../models/classifier/latest_dropout.h5')

# %%
model_class.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, None, 16)          176
# _________________________________________________________________
# dropout (Dropout)            (None, None, 16)          0
# _________________________________________________________________
# dense_1 (Dense)              (None, None, 16)          272
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 16)          0
# _________________________________________________________________
# dense_2 (Dense)              (None, None, 1)           17
# ...
# Total params: 465
# Trainable params: 465
# Non-trainable params: 0
# _________________________________________________________________

# %%
from KerasWeightsProcessing.convert_weights import txt_to_h5, h5_to_txt

# %%
h5_to_txt(
    weights_file_name='../models/classifier/latest_nodropout.h5', 
    output_file_name='classifier.txt'
)
# Out:
# /home/chiara/comp_scatt_ML/notebooks/KerasWeightsProcessing/convert_weights.py:209: UserWarning: Unsupported layer, inputlayer, found! Skipping...
#   warnings.warn(warning_str)

# %%
# !cat classifier.txt
# Out:
# 7
# input	10
# dense	16
# relu	0
# dense	16
# relu	0
# dense	1
# sigmoid	0
# 0.0010000000474974513
# 1.7661384e-01	7.8863986e-02	1.9427727e-03	1.1538225e-01	-5.2747660e-04	2.1159758e-01	-9.3941055e-02	1.1577906e-02	-4.9565886e-03	1.6554849e-02	2.1724068e-02	2.1837687e-01	-7.5155171e-04	5.3467043e-02	-4.1175811e-03	3.1622517e-01
# 4.7068346e-01	-7.3220685e-02	1.7790055e-01	4.0521014e-02	2.4627344e-01	2.7387726e-01	1.5556055e-01	2.6045361e-01	1.3330771e-01	8.6681455e-02	1.7758632e-01	-8.8703474e-03	-7.5163797e-02	1.7625022e-01	1.7794211e-01	2.1324863e-01
# 6.7678094e-03
# ...
